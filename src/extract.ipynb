# %%
from googleapiclient.discovery import build
from dotenv import load_dotenv

# %%
import os
import json
import pandas as pd

# %%
load_dotenv()
api_key = os.getenv("YOUTUBE_API_KEY")

youtube = build("youtube", "v3", developerKey=api_key)

# Request 1: First 50 videos 
request1 = youtube.videos().list(
    part="snippet,statistics,contentDetails",
    chart="mostPopular",
    regionCode="US",
    maxResults=50
)
resp1 = request1.execute()

# Request 2: Next 50 videos if available
next_token = resp1.get("nextPageToken")

if next_token:
    request2 = youtube.videos().list(
        part="snippet,statistics,contentDetails",
        chart="mostPopular",
        regionCode="US",
        maxResults=50,
        pageToken=next_token
    )
    resp2 = request2.execute()
    items = resp1["items"] + resp2["items"]
else:
    items = resp1["items"]

# %%
all_videos=[]
for item in items:
    video_dict ={

        'video_id': item['id'],
        'title': item['snippet']['title'],
        'published_at': item['snippet']['publishedAt'],
        'channel_title':item['snippet']['channelTitle'],
        'view_count': item['statistics'].get('viewCount', 0),
        'like_count':item['statistics'].get('likeCount',0),
        'dislike_count':item['statistics'].get('dislikeCount',0),
        'comment_count':item['statistics'].get('commentCount',0),
        'duration': item['contentDetails']['duration'],
        'tags': item['snippet'].get('tags',["NaN"])

    }
    all_videos.append(video_dict)

# %%
df = pd.DataFrame(all_videos)
df.head()
df= df.dropna(how='any')
df['title']=df['title'].str.lower()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       100 non-null    object
#  1   title          100 non-null    object
#  2   published_at   100 non-null    object
#  3   channel_title  100 non-null    object
#  4   view_count     100 non-null    object
#  5   like_count     100 non-null    object
#  6   dislike_count  100 non-null    int64
#  7   comment_count  100 non-null    object
#  8   duration       100 non-null    object
#  9   tags           100 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 7.9+ KB

# %%
df.to_csv('../data/youtube_data.csv',index=False)

# %%
df.head(20)
# Out:
#        video_id                                              title  \
# 0   SixTbTc6YCg                      ice spice, tokischa - thootie
# 1   VI6XO8EijT4                      digital circus ep 7 trailer!!
# 2   eWPZLDvRebU                   5000 days - [hardcore minecraft]
# 3   FeaRXx2VDhI  top 50 christmas songs of all time 🎄 best chri...
# 4   IaEtA56pd_w                           iron lung: final trailer
# 5   APJ-lT0sBhg  gta online: a safehouse in the hills coming de...
# 6   udFsogly8Us  jlexis x michael flores x shadow blow x alofok...
# 7   XRRnP91SSrQ  welcome home | poppy playtime chapter 5 cinema...
# 8   2teag5QC7NA       nice life: episode 1 - it's a wonderful life
# 9   Y_pkE7TFKuE  christmas songs playlist 🎄 top christmas songs...
# 10  xNCQrRcc_iE  things you missed in the amazing digital circu...
# 11  pt1CvOJ6hHA  🔴live | arc raiders | freak bob friday | #shar...
# 12  ph09xSEvw7w            glorilla - march (official music video)
# 13  sItUCKJQLTU  a knight of the seven kingdoms | official fina...
# 14  oWpvD3aTdo8    this is one of the best horror games this year…
# 15  h6AI0ay__10             screwly g - "codeine" (official video)
# 16  F77oqQjhWmI  gta 5 - mansion dlc trailer 2 breakdown! (mich...
# 17  n4tLHc8EeZA      brave take on five nights at freddy's 2 movie
# 18  88xDzqhaPTg               baky - legend (official music video)
# 19  W4F4oIPWDyQ                chapter 5's new trailer is crazy...
#
#             published_at                              channel_title  \
# 0   2025-12-05T17:00:06Z                               IceSpiceVEVO
# 1   2025-12-05T20:00:28Z                                     GLITCH
# 2   2025-12-05T23:00:54Z                            Luke TheNotable
# 3   2025-12-05T11:30:23Z  Christmas Songs and Carols - Love to Sing
# 4   2025-12-05T20:48:18Z                                 Markiplier
# 5   2025-12-05T14:56:45Z                             Rockstar Games
# 6   2025-12-04T22:50:53Z                         AlofokeMusicSounds
# 7   2025-12-05T16:00:21Z                          Mob Entertainment
# 8   2025-12-05T17:00:05Z                                      Grian
# 9   2025-12-05T11:00:07Z                               Revive Music
# 10  2025-12-05T22:03:22Z                                   Ayy Lmao
# 11  2025-12-06T10:13:46Z                             TheBurntPeanut
# 12  2025-12-05T05:00:06Z                               GloRillaVEVO
# 13  2025-12-04T20:53:14Z                                    HBO Max
# 14  2025-12-05T23:01:11Z                                     CaseOh
# 15  2025-12-06T02:01:00Z                                  Screwly G
# 16  2025-12-05T19:38:32Z                         Digital Car Addict
# 17  2025-12-05T23:15:03Z                                  penguinz0
# 18  2025-12-06T00:00:06Z                       Baky Popile Official
# 19  2025-12-05T16:01:09Z                               Sheeprampage
#
#    view_count like_count  dislike_count comment_count    duration  \
# 0      516179      48825              0          2663     PT2M33S
# 1     4246050     432146              0         25506       PT58S
# 2      635604      47461              0          5484      PT2H1S
# 3      563186       2185              0           122  PT2H19M11S
# 4     2084361     325040              0         16823     PT1M45S
# 5     1219873     104149              0          9073      PT1M1S
# 6     2877530     263049              0         22108      PT3M4S
# 7     1787749     161233              0         11924       PT58S
# 8     1156114      93163              0          6029    PT45M51S
# 9      130102       2026              0            33   PT3H6M11S
# 10     175822      10492              0           968     PT4M46S
# 11     587096      11152              0            96  PT8H32M42S
# 12     483910      20114              0          1594     PT3M12S
# 13    5581758      56655              0          3727     PT2M32S
# 14     342214      13291              0           825   PT2H44M7S
# 15      56961       5949              0           362     PT2M50S
# 16      90651       4645              0           842    PT13M34S
# 17     856878      45357              0          4306    PT18M32S
# 18     135339      14755              0          3929      PT3M6S
# 19     181601       8393              0           909    PT11M34S
#
#                                                  tags
# 0   [Ice Spice, Tokischa, 10K Projects/Capitol Rec...
# 1   [glitch, glitch productions, digital circus, t...
# 2   [luke thenotable, Minecraft, 100 Days, minecra...
# 3   [top christmas song, christmas songs, top chri...
# 4   [markiplier, iron lung, iron lung movie, offic...
# 5   [GTA Online, GTAV, GTA5 Online, GTA 5, GTA Onl...
# 6   [Bad Bunny, Dembow, Reggaeton, Karol G, Anuel ...
# 7                                               [NaN]
# 8   [Minecraft, Grian, building, grian, mincraft, ...
# 9                                               [NaN]
# 10  [digital circus episode 7, digital circus epis...
# 11                [funny, escape from tarkov, tarkov]
# 12             [GloRilla, Foundation ISR PS, Hip Hop]
# 13  [hbo max, ser duncan the tall, a knight of the...
# 14  [gaming, caseoh, caseohgames, case, funny, str...
# 15          [ScrewlyG, Screwly, TIYGangAce, TTa, Stk]
# 16  [Grand Theft Auto V, GTA Online, GTA 5, gta v,...
# 17                                              [NaN]
# 18  [Baky, Popile, Baky Popile, Baky Popile Offici...
# 19                                              [NaN]
